# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/dankim/swing2023/dataset/서울특별시_공공자전거 자치구별 대여건수_20230531.csv')

df
# Out:
#        년   월            계        강남구       강동구       강북구        강서구  \
# 0   2017  소계   5,031,039    128,535    79,361    31,969    116,730
# 1   2017  1월      84,149         NaN       NaN       NaN        NaN
# 2   2017  2월      85,752         NaN       NaN       NaN        NaN
# 3   2017  3월     188,767         NaN       NaN       NaN        NaN
# 4   2017  4월     319,181         NaN      760        NaN       709
# ..   ...  ..          ...        ...       ...       ...        ...
# 86  2023   8          NaN        NaN       NaN       NaN        NaN
# 87  2023   9          NaN        NaN       NaN       NaN        NaN
# 88  2023  10          NaN        NaN       NaN       NaN        NaN
# 89  2023  11          NaN        NaN       NaN       NaN        NaN
# 90  2023  12          NaN        NaN       NaN       NaN        NaN
#
#           관악구        광진구       구로구  ...       성북구        송파구       양천구  \
# 0    108,948    303,005    83,563   ...   75,552    161,489    75,184
# ...

# %%
a = df[(df['년']==2023)&(df['월']=='5')]
a.isnull().sum()
# Out:
# 년       0
# 월       0
# 계       0
# 강남구     0
# 강동구     0
# 강북구     0
# 강서구     0
# 관악구     0
# 광진구     0
# 구로구     0
# 금천구     0
# 노원구     0
# 도봉구     0
# 동대문구    0
# 동작구     0
# 마포구     0
# 서대문구    0
# 서초구     0
# 성동구     0
# 성북구     0
# 송파구     0
# 양천구     0
# 영등포구    0
# 용산구     0
# 은평구     0
# 종로구     0
# 중구      0
# 중랑구     0
# 기타      1
# dtype: int64

# %%
df = df.drop(['기타'], axis = 1)
df
# Out:
#        년   월            계        강남구       강동구       강북구        강서구  \
# 0   2017  소계   5,031,039    128,535    79,361    31,969    116,730
# 1   2017  1월      84,149         NaN       NaN       NaN        NaN
# 2   2017  2월      85,752         NaN       NaN       NaN        NaN
# 3   2017  3월     188,767         NaN       NaN       NaN        NaN
# 4   2017  4월     319,181         NaN      760        NaN       709
# ..   ...  ..          ...        ...       ...       ...        ...
# 86  2023   8          NaN        NaN       NaN       NaN        NaN
# 87  2023   9          NaN        NaN       NaN       NaN        NaN
# 88  2023  10          NaN        NaN       NaN       NaN        NaN
# 89  2023  11          NaN        NaN       NaN       NaN        NaN
# 90  2023  12          NaN        NaN       NaN       NaN        NaN
#
#           관악구        광진구       구로구  ...        성동구       성북구        송파구  \
# 0    108,948    303,005    83,563   ...   378,012    75,552    161,489
# ...

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# /var/folders/n9/zvxm89g142gdx27j51g86j200000gn/T/ipykernel_1981/1226147920.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %%
df = df.dropna()

# %%
df
# Out:
#        년   월            계        강남구        강동구       강북구        강서구  \
# 0   2017  소계   5,031,039    128,535     79,361    31,969    116,730
# 6   2017  6월     536,707      2,615      9,710     2,644     14,977
# 7   2017  7월     388,665      8,333      6,692     2,296     10,096
# 8   2017  8월     540,559     16,832      9,250     3,622     14,448
# 9   2017  9월     889,877     35,588     15,445     7,628     24,248
# ..   ...  ..          ...        ...        ...       ...        ...
# 79  2023   1   1,571,452     45,701     67,421    23,731    199,292
# 80  2023   2   2,231,519     69,050     97,236    35,716    259,264
# 81  2023   3   3,885,535    118,124    165,939    61,826    415,514
# 82  2023   4   4,082,096    134,028    177,915    64,254    429,349
# 83  2023   5   4,952,894    158,152    209,010    75,100    556,153
#
#           관악구        광진구        구로구  ...        성동구        성북구        송파구  \
# ...

# %%
a =  df.loc[(df['년'] == 2023) & (df['월'] == "5")]
pd.options.display.max_columns = None
a
# Out:
#        년  월            계        강남구        강동구       강북구        강서구  \
# 83  2023  5   4,952,894    158,152    209,010    75,100    556,153
#
#           관악구        광진구        구로구       금천구        노원구        도봉구  \
# 83   124,680    242,163    196,213    85,391    307,102    103,971
#
#          동대문구        동작구        마포구      서대문구        서초구        성동구  \
# 83   179,224    104,245    249,518    98,761    152,712    197,006
#
#           성북구        송파구        양천구       영등포구        용산구        은평구  \
# 83   124,028    454,774    270,476    400,554    107,039    121,705
#
#           종로구         중구        중랑구
# 83   169,369    117,495    148,053

# %%
b = a.iloc[0][3:]
b = b.to_frame()
b
# Out:
#              83
# 강남구    158,152
# 강동구    209,010
# 강북구     75,100
# 강서구    556,153
# 관악구    124,680
# 광진구    242,163
# 구로구    196,213
# 금천구     85,391
# 노원구    307,102
# 도봉구    103,971
# 동대문구   179,224
# 동작구    104,245
# 마포구    249,518
# 서대문구    98,761
# 서초구    152,712
# 성동구    197,006
# 성북구    124,028
# 송파구    454,774
# 양천구    270,476
# 영등포구   400,554
# 용산구    107,039
# 은평구    121,705
# 종로구    169,369
# 중구     117,495
# 중랑구    148,053

# %%
b[83] = b[83].str.strip()

# %%
b[83].str

# %%
b[83] = b[83].str.replace(',','').astype('int')

# %%
b = b.sort_values(83, ascending=False)
# Out:
#   Cell In[144], line 1
#     b = b.sort_values(83b, ascending=False)
#                        ^
# SyntaxError: invalid decimal literal

# %%
import seaborn as sns

# %%
b = b.sort_values(83, ascending=False)

plt.figure(figsize=(20, 8), facecolor='#FFFCEA')
sns.barplot(x=b[83], y=b.index)

plt.xlabel('Number of Public Bicycle Rentals', fontdict={'fontsize':15})
plt.ylabel('District', fontdict={'fontsize':15})
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.title('Number of Public Bicycle Rentals by Districts in May 2023', fontdict={'fontsize':20})
plt.show()
