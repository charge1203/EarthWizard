# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/dankim/swing2023/dataset/modified_서울시 도로변 기간별 일평균 대기환경 현황.csv')
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6584        9145  20220712    경계    행주         20   0.0240        0.0140
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['이산화질소농도(ppm)'].max()
# Out:
# 0.077

# %%
df[df['이산화질소농도(ppm)']==0.077]
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3259        4529  20230112  일반도로  시흥대로         80    0.002         0.077
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3259           1.1         0.005

# %%
df.loc[df['측정일자'] == 20230112]
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258        4528  20230112  일반도로   신촌로         67    0.006         0.056
# 3259        4529  20230112  일반도로  시흥대로         80    0.002         0.077
# 3260        4530  20230112  일반도로  한강대로         68    0.008         0.059
# 3261        4531  20230112  중앙차로  동작대로         87    0.004         0.070
# 3262        4532  20230112  일반도로    종로         60    0.005         0.063
# 3263        4533  20230112  일반도로  영등포로         77    0.003         0.064
# 3264        4534  20230112  중앙차로  공항대로         71    0.004         0.063
# 3265        4535  20230112    경계    항동         69    0.005         0.038
# 3266        4536  20230112  중앙차로  강남대로         77    0.005         0.062
# 3267        4537  20230112  일반도로  도산대로         77    0.003         0.057
# 3268        4539  20230112  일반도로  천호대로         75    0.003         0.061
# 3269        4541  20230112  일반도로  청계천로         66    0.005         0.049
# ...

# %%
# 각 오염물질별 오름차순 진행 -> 상위 3개씩 찾아보기
# 각각 그래프 그려봐서 오염물질이 많은 곳을 찾아보자

# %%
df.drop(df[(df['도로변구분'] == '경계')].index, inplace=True)
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6582        9142  20220712  일반도로  한강대로         21   0.0170        0.0210
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
df['오존(ppm)'].max() # 오존(O3) 8시간 평균치 = 0.06ppm 이하
# Out:
# 0.083

# %%
df['이산화질소농도(ppm)'].max() # 이산화질소(NO2) 24시간 평균치 = 0.06ppm 이하
# Out:
# 0.077

# %%
df['일산화탄소농도(ppm)'].max() # 일산화탄소(CO) 8시간 평균치 = 9ppm 이하
# Out:
# 1.4

# %%
df['아황산가스농도(ppm)'].max() # 아황산가스(SO2)24시간 평균치 = 0.05ppm 이하
# Out:
# 0.009

# %%
df = df.sort_values(['오존(ppm)'], ascending=False)
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 6553        9102  20220713  중앙차로  강남대로         13   0.0830        0.0220
# 628          872  20230608  일반도로  한강대로         32   0.0826        0.0237
# 1033        1435  20230516  중앙차로  공항대로         59   0.0770        0.0270
# 1035        1437  20230516  중앙차로  동작대로         56   0.0710        0.0380
# 124          173  20230706  중앙차로  공항대로         44   0.0705        0.0162
# ...          ...       ...   ...   ...        ...      ...           ...
# 4874        6771  20221015  일반도로  시흥대로          0   0.0000        0.0000
# 4826        6703  20221017  일반도로  시흥대로          0   0.0000        0.0000
# 150          209  20230704  일반도로  한강대로          0   0.0000        0.0000
# 143          199  20230705  일반도로  한강대로          0   0.0000        0.0000
# 5431        7543  20220914  일반도로  한강대로          0   0.0000        0.0000
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 6553          0.40        0.0020
# ...

# %%
df = df.sort_values(['이산화질소농도(ppm)'], ascending=False)
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3259        4529  20230112  일반도로  시흥대로         80    0.002         0.077
# 2046        2841  20230321  일반도로  시흥대로         81    0.016         0.074
# 3285        4564  20230111  일반도로  시흥대로         83    0.004         0.072
# 3290        4569  20230111  일반도로  영등포로         83    0.004         0.070
# 2795        3884  20230207  일반도로  도산대로         86    0.009         0.070
# ...          ...       ...   ...   ...        ...      ...           ...
# 5359        7443  20220918  일반도로  한강대로          0    0.000         0.000
# 5385        7478  20220916  일반도로  한강대로          0    0.000         0.000
# 5417        7524  20220915  일반도로  한강대로          0    0.000         0.000
# 5016        6965  20221007  일반도로  시흥대로          0    0.000         0.000
# 5431        7543  20220914  일반도로  한강대로          0    0.000         0.000
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3259           1.1         0.005
# ...

# %%
df = df.sort_values(['일산화탄소농도(ppm)'], ascending=False)
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3563        4949  20221227  중앙차로  강남대로         49    0.003         0.054
# 3576        4968  20221226  중앙차로  강남대로         51    0.002         0.050
# 2821        3918  20230206  중앙차로  강남대로         84    0.009         0.049
# 2796        3885  20230207  중앙차로  강남대로         87    0.006         0.055
# 3261        4531  20230112  중앙차로  동작대로         87    0.004         0.070
# ...          ...       ...   ...   ...        ...      ...           ...
# 4942        6861  20221011  일반도로  시흥대로          0    0.000         0.000
# 4954        6879  20221010  일반도로  시흥대로          0    0.000         0.000
# 4973        6907  20221009  일반도로  시흥대로          0    0.000         0.000
# 4905        6813  20221013  일반도로  시흥대로          0    0.000         0.000
# 5431        7543  20220914  일반도로  한강대로          0    0.000         0.000
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3563           1.4         0.005
# ...

# %%
df = df.sort_values(['아황산가스농도(ppm)'], ascending=False)
df
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 1876        2604  20230330  일반도로   홍릉로         71   0.0300        0.0460
# 4093        5684  20221127  일반도로  청계천로         22   0.0150        0.0240
# 2173        3016  20230314  일반도로  영등포로         41   0.0230        0.0320
# 785         1090  20230530  일반도로  청계천로         44   0.0209        0.0202
# 796         1107  20230529  일반도로  청계천로         14   0.0167        0.0174
# ...          ...       ...   ...   ...        ...      ...           ...
# 5385        7478  20220916  일반도로  한강대로          0   0.0000        0.0000
# 5417        7524  20220915  일반도로  한강대로          0   0.0000        0.0000
# 5016        6965  20221007  일반도로  시흥대로          0   0.0000        0.0000
# 5368        7456  20220917  일반도로  한강대로          0   0.0000        0.0000
# 5431        7543  20220914  일반도로  한강대로          0   0.0000        0.0000
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 1876          0.70        0.0090
# ...

# %% [markdown]
# > ### 이산화질소(NO2)
# - 24시간 0.06 Ppm 이내

# %%
# 도시대기측정소 vs 도로변 대기측정소

# %%
b = pd.read_csv('/Users/dankim/swing2023/dataset/modified_서울시 도로변 기간별 일평균 대기환경 현황.csv')
b
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6584        9145  20220712    경계    행주         20   0.0240        0.0140
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
b.drop(b[(b['도로변구분'] == '입체')].index, inplace=True)
b
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6584        9145  20220712    경계    행주         20   0.0240        0.0140
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
b.drop(b[(b['도로변구분'] == '경계')].index, inplace=True)
b
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6582        9142  20220712  일반도로  한강대로         21   0.0170        0.0210
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
b.drop(b[(b['도로변구분'] == '고공')].index, inplace=True)
b
# Out:
#       Unnamed: 0      측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 0              0  20230712  일반도로  한강대로         28   0.0162        0.0262
# 1              1  20230712  일반도로   홍릉로         19   0.0145        0.0236
# 2              2  20230712  중앙차로  동작대로         23   0.0093        0.0309
# 3              5  20230712  일반도로  천호대로         20   0.0115        0.0251
# 4              9  20230712  중앙차로  공항대로         23   0.0201        0.0219
# ...          ...       ...   ...   ...        ...      ...           ...
# 6582        9142  20220712  일반도로  한강대로         21   0.0170        0.0210
# 6583        9143  20220712  중앙차로  공항대로         19   0.0240        0.0290
# 6585        9146  20220712  일반도로  영등포로         15   0.0250        0.0240
# 6586        9148  20220712  일반도로  천호대로         13   0.0210        0.0220
# 6587        9149  20220712  일반도로   신촌로         18   0.0290        0.0200
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 0             0.56        0.0031
# ...

# %%
b = b.drop(['Unnamed: 0'], axis = 1)
b
# Out:
#           측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  일산화탄소농도(ppm)  \
# 0     20230712  일반도로  한강대로         28   0.0162        0.0262          0.56
# 1     20230712  일반도로   홍릉로         19   0.0145        0.0236          0.40
# 2     20230712  중앙차로  동작대로         23   0.0093        0.0309          0.53
# 3     20230712  일반도로  천호대로         20   0.0115        0.0251          0.44
# 4     20230712  중앙차로  공항대로         23   0.0201        0.0219          0.33
# ...        ...   ...   ...        ...      ...           ...           ...
# 6582  20220712  일반도로  한강대로         21   0.0170        0.0210          0.40
# 6583  20220712  중앙차로  공항대로         19   0.0240        0.0290          0.30
# 6585  20220712  일반도로  영등포로         15   0.0250        0.0240          0.40
# 6586  20220712  일반도로  천호대로         13   0.0210        0.0220          0.30
# 6587  20220712  일반도로   신촌로         18   0.0290        0.0200          0.30
#
#       아황산가스농도(ppm)
# 0           0.0031
# 1           0.0026
# ...

# %%
b_no2 = b.loc[b['측정일자'] == 20230112]
b_no2
# Out:
#           측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  일산화탄소농도(ppm)  \
# 3258  20230112  일반도로   신촌로         67    0.006         0.056           0.8
# 3259  20230112  일반도로  시흥대로         80    0.002         0.077           1.1
# 3260  20230112  일반도로  한강대로         68    0.008         0.059           0.9
# 3261  20230112  중앙차로  동작대로         87    0.004         0.070           1.3
# 3262  20230112  일반도로    종로         60    0.005         0.063           1.1
# 3263  20230112  일반도로  영등포로         77    0.003         0.064           1.0
# 3264  20230112  중앙차로  공항대로         71    0.004         0.063           1.0
# 3266  20230112  중앙차로  강남대로         77    0.005         0.062           1.1
# 3267  20230112  일반도로  도산대로         77    0.003         0.057           1.0
# 3268  20230112  일반도로  천호대로         75    0.003         0.061           1.0
# 3269  20230112  일반도로  청계천로         66    0.005         0.049           1.2
# ...

# %%
plt.figure(figsize=(20, 10))
plt.plot(b_no2['측정소명'], b_no2['이산화질소농도(ppm)'], label='No2', linestyle='--',marker='o')
plt.xlabel('차로/도로명') #x 라벨
plt.ylabel('NO2 수치') #y 라벨
plt.title("2023년 1월 12일 NO2 수치") #그래프 이름
plt.legend()
plt.show()

# %%
# 구별 데이터와 비교 위해 강변북로와 화랑로 날리기
b_no2 = b_no2.copy()  # 복사본 생성

# 복사본에 대한 조작
b_no2.drop(b_no2[b_no2['측정소명'] == '강변북로'].index, inplace=True)
b_no2.drop(b_no2[b_no2['측정소명'] == '화랑로'].index, inplace=True)
b_no2.drop(b_no2[b_no2['측정소명'] == '도산대로'].index, inplace=True)
b_no2.drop(b_no2[b_no2['측정소명'] == '정릉로'].index, inplace=True)

# %%
b_no2
b_no2
# Out:
#           측정일자 도로변구분  측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  일산화탄소농도(ppm)  \
# 3258  20230112  일반도로   신촌로         67    0.006         0.056           0.8
# 3259  20230112  일반도로  시흥대로         80    0.002         0.077           1.1
# 3260  20230112  일반도로  한강대로         68    0.008         0.059           0.9
# 3261  20230112  중앙차로  동작대로         87    0.004         0.070           1.3
# 3262  20230112  일반도로    종로         60    0.005         0.063           1.1
# 3263  20230112  일반도로  영등포로         77    0.003         0.064           1.0
# 3264  20230112  중앙차로  공항대로         71    0.004         0.063           1.0
# 3266  20230112  중앙차로  강남대로         77    0.005         0.062           1.1
# 3268  20230112  일반도로  천호대로         75    0.003         0.061           1.0
# 3269  20230112  일반도로  청계천로         66    0.005         0.049           1.2
# 3272  20230112  일반도로   홍릉로         68    0.003         0.059           1.0
#
#       아황산가스농도(ppm)
# 3258         0.004
# 3259         0.005
# ...

# %%
b_no2.loc[3258, '측정소명'] = '마포구(신촌로)'

b_no2
# Out:
#           측정일자 도로변구분      측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258  20230112  일반도로  마포구(신촌로)         67    0.006         0.056
# 3259  20230112  일반도로      시흥대로         80    0.002         0.077
# 3260  20230112  일반도로      한강대로         68    0.008         0.059
# 3261  20230112  중앙차로      동작대로         87    0.004         0.070
# 3262  20230112  일반도로        종로         60    0.005         0.063
# 3263  20230112  일반도로      영등포로         77    0.003         0.064
# 3264  20230112  중앙차로      공항대로         71    0.004         0.063
# 3266  20230112  중앙차로      강남대로         77    0.005         0.062
# 3268  20230112  일반도로      천호대로         75    0.003         0.061
# 3269  20230112  일반도로      청계천로         66    0.005         0.049
# 3272  20230112  일반도로       홍릉로         68    0.003         0.059
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3258           0.8         0.004
# 3259           1.1         0.005
# 3260           0.9         0.003
# 3261           1.3         0.005
# ...

# %%
b_no2.loc[3259, '측정소명'] = '금천구(시흥대로)'

b_no2
# Out:
#           측정일자 도로변구분       측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258  20230112  일반도로   마포구(신촌로)         67    0.006         0.056
# 3259  20230112  일반도로  금천구(시흥대로)         80    0.002         0.077
# 3260  20230112  일반도로       한강대로         68    0.008         0.059
# 3261  20230112  중앙차로       동작대로         87    0.004         0.070
# 3262  20230112  일반도로         종로         60    0.005         0.063
# 3263  20230112  일반도로       영등포로         77    0.003         0.064
# 3264  20230112  중앙차로       공항대로         71    0.004         0.063
# 3266  20230112  중앙차로       강남대로         77    0.005         0.062
# 3268  20230112  일반도로       천호대로         75    0.003         0.061
# 3269  20230112  일반도로       청계천로         66    0.005         0.049
# 3272  20230112  일반도로        홍릉로         68    0.003         0.059
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3258           0.8         0.004
# 3259           1.1         0.005
# 3260           0.9         0.003
# 3261           1.3         0.005
# ...

# %%
b_no2.loc[3260, '측정소명'] = '용산구(한강대로)'
b_no2.loc[3261, '측정소명'] = '동작구(동작대로)'
b_no2.loc[3262, '측정소명'] = '종로구(종로)'
b_no2.loc[3263, '측정소명'] = '영등포구(영등포로)'
b_no2.loc[3264, '측정소명'] = '강서구(공항대로)'
b_no2.loc[3266, '측정소명'] = '서초구(강남대로)'
b_no2.loc[3268, '측정소명'] = '광진구(천호대로)'
b_no2.loc[3269, '측정소명'] = '중구(청계천로)'
b_no2.loc[3272, '측정소명'] = '동대문구(홍릉로)'

b_no2
# Out:
#           측정일자 도로변구분        측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258  20230112  일반도로    마포구(신촌로)         67    0.006         0.056
# 3259  20230112  일반도로   금천구(시흥대로)         80    0.002         0.077
# 3260  20230112  일반도로   용산구(한강대로)         68    0.008         0.059
# 3261  20230112  중앙차로   동작구(동작대로)         87    0.004         0.070
# 3262  20230112  일반도로     종로구(종로)         60    0.005         0.063
# 3263  20230112  일반도로  영등포구(영등포로)         77    0.003         0.064
# 3264  20230112  중앙차로   강서구(공항대로)         71    0.004         0.063
# 3266  20230112  중앙차로   서초구(강남대로)         77    0.005         0.062
# 3268  20230112  일반도로   광진구(천호대로)         75    0.003         0.061
# 3269  20230112  일반도로    중구(청계천로)         66    0.005         0.049
# 3272  20230112  일반도로   동대문구(홍릉로)         68    0.003         0.059
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3258           0.8         0.004
# 3259           1.1         0.005
# 3260           0.9         0.003
# ...

# %%
b_no2 = b_no2.copy()  # 복사본 생성

# 복사본에 대한 조작 (구별 데이터에 중구가 없으므로 청계천로 삭제)
b_no2.drop(b_no2[b_no2['측정소명'] == '중구(청계천로)'].index, inplace=True)
b_no2
# Out:
#           측정일자 도로변구분        측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258  20230112  일반도로    마포구(신촌로)         67    0.006         0.056
# 3259  20230112  일반도로   금천구(시흥대로)         80    0.002         0.077
# 3260  20230112  일반도로   용산구(한강대로)         68    0.008         0.059
# 3261  20230112  중앙차로   동작구(동작대로)         87    0.004         0.070
# 3262  20230112  일반도로     종로구(종로)         60    0.005         0.063
# 3263  20230112  일반도로  영등포구(영등포로)         77    0.003         0.064
# 3264  20230112  중앙차로   강서구(공항대로)         71    0.004         0.063
# 3266  20230112  중앙차로   서초구(강남대로)         77    0.005         0.062
# 3268  20230112  일반도로   광진구(천호대로)         75    0.003         0.061
# 3272  20230112  일반도로   동대문구(홍릉로)         68    0.003         0.059
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3258           0.8         0.004
# 3259           1.1         0.005
# 3260           0.9         0.003
# 3261           1.3         0.005
# 3262           1.1         0.006
# ...

# %%
c = pd.read_csv('/Users/dankim/swing2023/dataset/서울시 구별(도로) 대기오염도 정보_20230112.csv', encoding='cp949')
c
# Out:
#         측정일시        측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0   20230112    마포구(신촌로)         0.056      0.007           0.8       0.005
# 1   20230112   금천구(시흥대로)         0.060      0.003           0.8       0.004
# 2   20230112   용산구(한강대로)         0.055      0.006           0.9       0.003
# 3   20230112   동작구(동작대로)         0.067      0.005           1.0       0.005
# 4   20230112     종로구(종로)         0.056      0.007           1.0       0.005
# 5   20230112  영등포구(영등포로)         0.063      0.004           1.0       0.004
# 6   20230112   강서구(공항대로)         0.056      0.006           1.0       0.004
# 7   20230112   서초구(강남대로)         0.060      0.004           0.4       0.003
# 8   20230112   강남구(도산대로)         0.058      0.005           0.7       0.004
# 9   20230112   광진구(천호대로)         0.044      0.006           0.6       0.004
# 10  20230112   동대문구(홍릉로)         0.055      0.007           0.9       0.005
# ...

# %%
# 구별 데이터에서 정릉로와 도산대로 삭제

c.drop(c[(c['측정소명'] == '강남구(도산대로)')].index, inplace=True)
c.drop(c[(c['측정소명'] == '성북구(정릉로)')].index, inplace=True)
c
# Out:
#         측정일시        측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0   20230112    마포구(신촌로)         0.056      0.007           0.8       0.005
# 1   20230112   금천구(시흥대로)         0.060      0.003           0.8       0.004
# 2   20230112   용산구(한강대로)         0.055      0.006           0.9       0.003
# 3   20230112   동작구(동작대로)         0.067      0.005           1.0       0.005
# 4   20230112     종로구(종로)         0.056      0.007           1.0       0.005
# 5   20230112  영등포구(영등포로)         0.063      0.004           1.0       0.004
# 6   20230112   강서구(공항대로)         0.056      0.006           1.0       0.004
# 7   20230112   서초구(강남대로)         0.060      0.004           0.4       0.003
# 9   20230112   광진구(천호대로)         0.044      0.006           0.6       0.004
# 10  20230112   동대문구(홍릉로)         0.055      0.007           0.9       0.005
#
#     미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0          54          45
# 1          68          53
# 2          61          41
# ...

# %%
b_no2
# Out:
#           측정일자 도로변구분        측정소명  미세먼지(㎍/㎥)  오존(ppm)  이산화질소농도(ppm)  \
# 3258  20230112  일반도로    마포구(신촌로)         67    0.006         0.056
# 3259  20230112  일반도로   금천구(시흥대로)         80    0.002         0.077
# 3260  20230112  일반도로   용산구(한강대로)         68    0.008         0.059
# 3261  20230112  중앙차로   동작구(동작대로)         87    0.004         0.070
# 3262  20230112  일반도로     종로구(종로)         60    0.005         0.063
# 3263  20230112  일반도로  영등포구(영등포로)         77    0.003         0.064
# 3264  20230112  중앙차로   강서구(공항대로)         71    0.004         0.063
# 3266  20230112  중앙차로   서초구(강남대로)         77    0.005         0.062
# 3268  20230112  일반도로   광진구(천호대로)         75    0.003         0.061
# 3272  20230112  일반도로   동대문구(홍릉로)         68    0.003         0.059
#
#       일산화탄소농도(ppm)  아황산가스농도(ppm)
# 3258           0.8         0.004
# 3259           1.1         0.005
# 3260           0.9         0.003
# 3261           1.3         0.005
# 3262           1.1         0.006
# ...

# %%
c
# Out:
#         측정일시        측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0   20230112    마포구(신촌로)         0.056      0.007           0.8       0.005
# 1   20230112   금천구(시흥대로)         0.060      0.003           0.8       0.004
# 2   20230112   용산구(한강대로)         0.055      0.006           0.9       0.003
# 3   20230112   동작구(동작대로)         0.067      0.005           1.0       0.005
# 4   20230112     종로구(종로)         0.056      0.007           1.0       0.005
# 5   20230112  영등포구(영등포로)         0.063      0.004           1.0       0.004
# 6   20230112   강서구(공항대로)         0.056      0.006           1.0       0.004
# 7   20230112   서초구(강남대로)         0.060      0.004           0.4       0.003
# 9   20230112   광진구(천호대로)         0.044      0.006           0.6       0.004
# 10  20230112   동대문구(홍릉로)         0.055      0.007           0.9       0.005
#
#     미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0          54          45
# 1          68          53
# 2          61          41
# ...

# %%
b_no2_mod = b_no2.drop(['일산화탄소농도(ppm)', '오존(ppm)', '아황산가스농도(ppm)','미세먼지(㎍/㎥)'], axis = 1)
b_no2_mod
# Out:
#           측정일자 도로변구분        측정소명  이산화질소농도(ppm)
# 3258  20230112  일반도로    마포구(신촌로)         0.056
# 3259  20230112  일반도로   금천구(시흥대로)         0.077
# 3260  20230112  일반도로   용산구(한강대로)         0.059
# 3261  20230112  중앙차로   동작구(동작대로)         0.070
# 3262  20230112  일반도로     종로구(종로)         0.063
# 3263  20230112  일반도로  영등포구(영등포로)         0.064
# 3264  20230112  중앙차로   강서구(공항대로)         0.063
# 3266  20230112  중앙차로   서초구(강남대로)         0.062
# 3268  20230112  일반도로   광진구(천호대로)         0.061
# 3272  20230112  일반도로   동대문구(홍릉로)         0.059

# %%
b_no2_mod = b_no2.drop(['도로변구분','측정일자','일산화탄소농도(ppm)', '오존(ppm)', '아황산가스농도(ppm)','미세먼지(㎍/㎥)'], axis = 1)
b_no2_mod
# Out:
#             측정소명  이산화질소농도(ppm)
# 3258    마포구(신촌로)         0.056
# 3259   금천구(시흥대로)         0.077
# 3260   용산구(한강대로)         0.059
# 3261   동작구(동작대로)         0.070
# 3262     종로구(종로)         0.063
# 3263  영등포구(영등포로)         0.064
# 3264   강서구(공항대로)         0.063
# 3266   서초구(강남대로)         0.062
# 3268   광진구(천호대로)         0.061
# 3272   동대문구(홍릉로)         0.059

# %%
c_mod = c.drop(['측정일시', '오존농도(ppm)' , '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],axis = 1)
c_mod

c_mod.rename(columns = {'이산화질소농도(ppm)':'이산화질소농도(ppm, 구별)'},inplace=True)
c_mod
# Out:
#           측정소명  이산화질소농도(ppm, 구별)
# 0     마포구(신촌로)             0.056
# 1    금천구(시흥대로)             0.060
# 2    용산구(한강대로)             0.055
# 3    동작구(동작대로)             0.067
# 4      종로구(종로)             0.056
# 5   영등포구(영등포로)             0.063
# 6    강서구(공항대로)             0.056
# 7    서초구(강남대로)             0.060
# 9    광진구(천호대로)             0.044
# 10   동대문구(홍릉로)             0.055

# %%
# 측정소명을 기준으로 데이터프레임 합치기
df_combined = b_no2_mod.merge(c_mod, on='측정소명')

# 결과 출력
df_combined
# Out:
#          측정소명  이산화질소농도(ppm)  이산화질소농도(ppm, 구별)
# 0    마포구(신촌로)         0.056             0.056
# 1   금천구(시흥대로)         0.077             0.060
# 2   용산구(한강대로)         0.059             0.055
# 3   동작구(동작대로)         0.070             0.067
# 4     종로구(종로)         0.063             0.056
# 5  영등포구(영등포로)         0.064             0.063
# 6   강서구(공항대로)         0.063             0.056
# 7   서초구(강남대로)         0.062             0.060
# 8   광진구(천호대로)         0.061             0.044
# 9   동대문구(홍릉로)         0.059             0.055

# %%
type(df_combined)

df_combined.rename(columns = {'이산화질소농도(ppm, 구별)':'이산화질소농도(ppm)'},inplace=True)
df_combined
# Out:
#          측정소명  이산화질소농도(ppm)  이산화질소농도(ppm)
# 0    마포구(신촌로)         0.056         0.056
# 1   금천구(시흥대로)         0.077         0.060
# 2   용산구(한강대로)         0.059         0.055
# 3   동작구(동작대로)         0.070         0.067
# 4     종로구(종로)         0.063         0.056
# 5  영등포구(영등포로)         0.064         0.063
# 6   강서구(공항대로)         0.063         0.056
# 7   서초구(강남대로)         0.062         0.060
# 8   광진구(천호대로)         0.061         0.044
# 9   동대문구(홍릉로)         0.059         0.055

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 20))
mpl.rcParams['font.size'] = 40
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# 데이터프레임에서 '측정소명'과 이산화질소농도(ppm) 열을 추출
labels = df['측정소명']
values1 = df['이산화질소농도(ppm)']
values2 = df['이산화질소농도(ppm, 구별)']

# x 좌표 값
x = np.arange(len(labels))

# 막대 그래프 너비 설정
bar_width = 0.35

# 막대 그래프 그리기
plt.bar(x, values1, width=bar_width, color='blue', label='이산화질소농도(ppm)')
plt.bar(x + bar_width, values2, width=bar_width, color='red', label='이산화질소농도(ppm, 구별)')

# x 축 설정
plt.xticks(x + bar_width/2, labels, rotation=45, fontsize=30)
plt.yticks(fontsize=30)

# 축과 제목 설정
plt.xlabel('measuring stations', fontsize=40)
plt.ylabel('NO2(ppm)', fontsize=40)
plt.title('Comparison of NO2 Emissions in Districts and Roadways on 12/01/2023', fontsize=40)

# 범례 추가
plt.legend()

# 그래프 표시
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 20))
plt.gca().set_facecolor('#FFFCEA')
# mpl.rcParams['font.size'] = 40
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

fig = plt.figure(figsize=(40, 20), facecolor='#FFFCEA')

# 데이터프레임에서 '측정소명'과 이산화질소농도(ppm) 열을 추출
labels = df['측정소명']
values1 = df['이산화질소농도(ppm)']
values2 = df['이산화질소농도(ppm, 구별)']

# x 좌표 값
x = np.arange(len(labels))

# 막대 그래프 너비 설정
bar_width = 0.35

# 막대 그래프 그리기
plt.bar(x, values1, width=bar_width, color='#FFD169', label='Roadway')
plt.bar(x + bar_width, values2, width=bar_width, color='#80ABEB', label='District')

#plt.bar(x, values1, width=bar_width, color='white', edgecolor='#FFD169', label='이산화질소농도(ppm)')
#plt.bar(x + bar_width, values2, width=bar_width, color='white', edgecolor='#80ABEB', label='이산화질소농도(ppm, 구별)')


# x 축 설정
plt.xticks(x + bar_width/2, labels, rotation=20, fontsize=30) #rotation=45
plt.yticks(fontsize=30)

# 축과 제목 설정
plt.xlabel('measuring stations', fontsize=40)
plt.ylabel('NO2(ppm) Level', fontsize=40)
plt.title('Comparison of NO2 Emissions in Districts and Roadways', fontsize=60) #12/01/2023

# 배경색 설정
# fig.patch.set_facecolor('#FFFCEA')
# plt.gca().set_facecolor('#FFFCEA')

# 범례 추가
plt.legend()

# 그래프 표시
plt.tight_layout()
plt.show()
